# %% [markdown]
# # Exercise 1 : Correlation Analysis

# %%
#Step 1 : Load the Communities in the US (cleaned version) into a Pandas dataframe.
import pandas as pd 
import scipy.stats as stats
df = pd.read_csv(r"C:\Users\adcr573\Downloads\censusCrimeClean.csv")
df
# Out:
#             communityname  fold  population  householdsize  racepctblack  \
# 0            Lakewoodcity     1        0.19           0.33          0.02
# 1             Tukwilacity     1        0.00           0.16          0.12
# 2            Aberdeentown     1        0.00           0.42          0.49
# 3     Willingborotownship     1        0.04           0.77          1.00
# 4       Bethlehemtownship     1        0.01           0.55          0.02
# ...                   ...   ...         ...            ...           ...
# 1989    TempleTerracecity    10        0.01           0.40          0.10
# 1990          Seasidecity    10        0.05           0.96          0.46
# 1991        Waterburytown    10        0.16           0.37          0.25
# 1992          Walthamcity    10        0.08           0.51          0.06
# 1993          Ontariocity    10        0.20           0.78          0.14
#
#       racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# ...

# %%
#Step 2: Choose two columns as save as variables. You can choose any but an interesting pair could be "medIncome" and "ViolentCrimesPerPop".
medIncome_df = df["medIncome"]
print("1st column:",medIncome_df)

ViolentCrimesPerPop_df = df["ViolentCrimesPerPop"]
print("2nd column:",ViolentCrimesPerPop_df)
# Out:
# 1st column: 0       0.37
# 1       0.31
# 2       0.30
# 3       0.58
# 4       0.50
#         ...
# 1989    0.42
# 1990    0.28
# 1991    0.31
# 1992    0.44
# 1993    0.40
# Name: medIncome, Length: 1994, dtype: float64
# 2nd column: 0       0.20
# 1       0.67
# 2       0.43
# 3       0.12
# 4       0.03
#         ...
# 1989    0.09
# 1990    0.45
# 1991    0.23
# 1992    0.19
# 1993    0.48
# Name: ViolentCrimesPerPop, Length: 1994, dtype: float64

# %%
medIncome_df
# Out:
# 0       0.37
# 1       0.31
# 2       0.30
# 3       0.58
# 4       0.50
#         ...
# 1989    0.42
# 1990    0.28
# 1991    0.31
# 1992    0.44
# 1993    0.40
# Name: medIncome, Length: 1994, dtype: float64

# %%
ViolentCrimesPerPop_df
# Out:
# 0       0.20
# 1       0.67
# 2       0.43
# 3       0.12
# 4       0.03
#         ...
# 1989    0.09
# 1990    0.45
# 1991    0.23
# 1992    0.19
# 1993    0.48
# Name: ViolentCrimesPerPop, Length: 1994, dtype: float64

# %%
#Step 3 Perform a Pearson correlation and note the correlation value.

from scipy.stats import pearsonr
pearsonr(medIncome_df, ViolentCrimesPerPop_df)
# Out:
# (-0.42422061672612593, 6.334424808048533e-88)

# %%
#Step 4 Perform a Spearman correlation computation and note the correlation value.
from scipy.stats import spearmanr
spearmanr(medIncome_df, ViolentCrimesPerPop_df)
# Out:
# SpearmanrResult(correlation=-0.482169950997556, pvalue=1.2978853095169542e-116)

# %%
# Step 5 Comment on the differences / similarities in relation to a scatterplot visualisation of the two columns.
# Simillarities they have is in the corellation and they both have p values to reject the null hypothesis Spearmanr does the relationship between non linear variables.
# Unlike the Pearson correlation, the Spearman correlation does not assume that both datasets are normally distributed.
# Pearson correlation coefficient measures the linear relationship between two dataset

# %%
# Step 6 Have a go at comparing other columns to crimes. You might want to select some columns and calculate correlation coefficients and draw scatterplots in a loop
from scipy.stats import pearsonr
from scipy.stats import spearmanr
import pandas as pd 
import matplotlib.pyplot as plt
ViolentCrimesPerPop_df = df["ViolentCrimesPerPop"]

# Iterate over the sequence of column names
for column in df :
    columnSeriesObj = df[column]
    print ('Colunm Name : ', column)
    print('Column Contents : ', columnSeriesObj.values)
    pearsonr(next(columnSeriesObj.values),ViolentCrimesPerPop_df)
   

    #print(pearsonr, a)
# Out:
# Colunm Name :  communityname
# Column Contents :  ['Lakewoodcity' 'Tukwilacity' 'Aberdeentown' ... 'Waterburytown'
#  'Walthamcity' 'Ontariocity']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f0343716a9ed> in <module>
#      11     print ('Colunm Name : ', column)
#      12     print('Column Contents : ', columnSeriesObj.values)
# ---> 13     pearsonr(next(columnSeriesObj.values),ViolentCrimesPerPop_df)
#      14
#      15
#
# TypeError: 'numpy.ndarray' object is not an iterator

# %% [markdown]
# # Exercise 2: Significance testing

# %% [markdown]
# # Preparation

# %% [raw]
# Load the data into a pandas dataframe and create additional columns. Create gender and hasHeartDisease columns with the correct values (as above) to make it easier to read.

# %%
import pandas as pd 
heart = pd.read_csv(r"C:\Users\adcr573\Downloads\heart.csv")
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#The sex column has a 0 for female and 1 for male. The target column indicated if the patient has heart disease and where (confusingly) 0 is for those with heart disease
heart["gender"] = heart["sex"].replace((0,1),("female","male"))
heart["hasHeartDisease"] = heart["target"].replace((0,1),("YES","NO"))
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  gender hasHeartDisease
# ...

# %% [markdown]
# # Does the resting blood pressure (trestbps) differ between those with the disease and those without?

# %% [raw]
# 1.Calculate the means and standard deviations. How do they compare between groups and by how much? If someone asked you whether they vary, what would you say? Discuss in your groups.

# %%
import scipy.stats as stats
heart1 = heart[heart["hasHeartDisease"]=="NO"]
heart1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 162   41    1   1       120   157    0        1      182      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target  gender hasHeartDisease
# ...

# %%
heart2 = heart[heart["hasHeartDisease"]=="YES"]
heart2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 165   67    1   0       160   286    0        0      108      1      1.5
# 166   67    1   0       120   229    0        0      129      1      2.6
# 167   62    0   0       140   268    0        0      160      0      3.6
# 168   63    1   0       130   254    0        0      147      0      1.4
# 169   53    1   0       140   203    1        0      155      1      3.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  gender hasHeartDisease
# ...

# %%
heart1.mean()
# Out:
# age          52.496970
# sex           0.563636
# cp            1.375758
# trestbps    129.303030
# chol        242.230303
# fbs           0.139394
# restecg       0.593939
# thalach     158.466667
# exang         0.139394
# oldpeak       0.583030
# slope         1.593939
# ca            0.363636
# thal          2.121212
# target        1.000000
# dtype: float64

# %%
heart2.mean()
# Out:
# age          56.601449
# sex           0.826087
# cp            0.478261
# trestbps    134.398551
# chol        251.086957
# fbs           0.159420
# restecg       0.449275
# thalach     139.101449
# exang         0.550725
# oldpeak       1.585507
# slope         1.166667
# ca            1.166667
# thal          2.543478
# target        0.000000
# dtype: float64

# %%
heart1.std()
# Out:
# age          9.550651
# sex          0.497444
# cp           0.952222
# trestbps    16.169613
# chol        53.552872
# fbs          0.347412
# restecg      0.504818
# thalach     19.174276
# exang        0.347412
# oldpeak      0.780683
# slope        0.593635
# ca           0.848894
# thal         0.465752
# target       0.000000
# dtype: float64

# %%
heart2.std()
# Out:
# age          7.962082
# sex          0.380416
# cp           0.905920
# trestbps    18.729944
# chol        49.454614
# fbs          0.367401
# restecg      0.541321
# thalach     22.598782
# exang        0.499232
# oldpeak      1.300340
# slope        0.561324
# ca           1.043460
# thal         0.684762
# target       0.000000
# dtype: float64

# %% [raw]
# 2.Create boxplots and histograms to compare the means and distributions. Make sure you use the same scales on the axes. Tip: If using matplotlib, you might want to use subplots(ncols=2,sharey=True) to create two plots side-by-side with a shared y axis. Same question as above, do these value vary and by how much?

# %%
import seaborn as sns 
sns.boxplot(x="trestbps",data=heart1)
# Out:
# <AxesSubplot:xlabel='trestbps'>

# %%
sns.boxplot(x="trestbps",data=heart2)
# Out:
# <AxesSubplot:xlabel='trestbps'>

# %%
import matplotlib.pyplot as plt
plt.hist(heart1["trestbps"])
# Out:
# (array([ 7., 17., 13., 39., 35., 30., 13.,  7.,  1.,  3.]),
#  array([ 94. , 102.6, 111.2, 119.8, 128.4, 137. , 145.6, 154.2, 162.8,
#         171.4, 180. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(heart2["trestbps"])
# Out:
# (array([ 4., 19., 35., 27., 24., 12.,  8.,  5.,  2.,  2.]),
#  array([100., 110., 120., 130., 140., 150., 160., 170., 180., 190., 200.]),
#  <BarContainer object of 10 artists>)

# %% [raw]
# 3.Compare the means using scipy.stat's ttest_ind() function. What is the p-value telling you? Does this relate to the judgements you made above?

# %%
import scipy.stats as stats
import numpy as np
stats.ttest_ind(heart1["trestbps"],heart2["trestbps"])
# Out:
# Ttest_indResult(statistic=-2.5412927171039, pvalue=0.011546059200233312)

# %% [raw]
# 4.Calculate Cohen's d. (Search for "cohen's d" on this page which gives the formula and also the formula for the pooled standard deviation which you also need. Note that it doesn't give the Python code directly - you may need to use math.sqrt() and pow()). Interpret this value and consider how it relates to your other interpretations (above).

# %%
# function to calculate Cohen's d for independent samples
d1= heart1["trestbps"]
d2 = heart2["trestbps"]
def cohend(d1, d2):
# calculate the size of samples
   n1, n2 = len(d1), len(d1)
# calculate the variance of the samples
   s1, s2 = np.var(d1, ddof=1), np.var(d2, ddof=1)
# calculate the pooled standard deviation
   s = np.sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
# calculate the means of the samples
   u1, u2 = np.mean(d1), np.mean(d2)
# calculate the effect size
   return (u1 - u2) / s
cohend(d1,d2)
# Out:
# -0.29122794740288344

# %% [raw]
# 5.Try some other (quantitative) variables and compare between heart disease groups. You could also compare by gender but there's probably no good reason to.

# %% [raw]
# did it in the command window

# %% [markdown]
# # Is the proportion of men and women who get heart disease the same?

# %% [raw]
# Calculate the proportion of men and women who have heart disease from the sample. To save you time, this code (is one of many ways that) will do it.

# %%
#Count the number with the disease for each gender type
hasDiseaseCount=heart[heart.hasHeartDisease==True].groupby("gender").count().hasHeartDisease

#Count the number of gender type
totalCount=heart.groupby("gender").count()['hasHeartDisease']

#combine into a dataframe (both are indexed with gender, so will be matched) and specify the columns
p=pd.concat([hasDiseaseCount, totalCount], axis=1)
p.columns = ["heartDiseaseCount", "totalCount"]

#create a new column and calculate the proportion
p['propHeartDisease']=p["heartDiseaseCount"]/p["totalCount"]

#print the results
print(p.head())
# Out:
#         heartDiseaseCount  totalCount  propHeartDisease
# gender
# female                NaN          96               NaN
# male                  NaN         207               NaN
